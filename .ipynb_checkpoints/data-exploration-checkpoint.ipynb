# %% [markdown]
# ### Final Project JC-DS Batch 6 Purwadhika Kampus Jakarta
#
# #### Data Exploration
#
# by Nur Wibowo
#
# -------

# %% [markdown]
# #### Import library, load dataset, dan cek dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dfweather = pd.read_csv('data/dataset_capitalbikesharing.csv', parse_dates=['date'])

# %%
dfweather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3318 entries, 0 to 3317
# Data columns (total 12 columns):
# date           3318 non-null datetime64[ns]
# month          3318 non-null int64
# year           3318 non-null int64
# holiday        3318 non-null int64
# workingday     3318 non-null int64
# season         3318 non-null int64
# temperature    3318 non-null int64
# windspeed      3318 non-null int64
# humidity       3318 non-null float64
# casual         3318 non-null int64
# member         3318 non-null int64
# total          3318 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(10)
# memory usage: 311.2 KB

# %%
dfweather.head()
# Out:
#         date  month  year  holiday  workingday  season  temperature  \
# 0 2010-09-20      9  2010        0           1       3           23
# 1 2010-09-21      9  2010        0           1       3           20
# 2 2010-09-22      9  2010        0           1       3           26
# 3 2010-09-23      9  2010        0           1       3           27
# 4 2010-09-24      9  2010        0           1       3           29
#
#    windspeed  humidity  casual  member  total
# 0         17      0.47      34     178    212
# 1         10      0.52     109     215    324
# 2         15      0.60     117     260    377
# 3          8      0.64     124     249    373
# 4         15      0.60     156     206    362

# %%
dfweather.describe()
# Out:
#            holiday        month         year   workingday       season  \
# count  3318.000000  3318.000000  3318.000000  3318.000000  3318.000000
# mean      0.030440     6.575949  2014.771248     0.714888     2.493369
# std       0.171821     3.440890     2.650440     0.451536     1.110608
# min       0.000000     1.000000  2010.000000     0.000000     1.000000
# 25%       0.000000     4.000000  2012.000000     0.000000     2.000000
# 50%       0.000000     7.000000  2015.000000     1.000000     3.000000
# 75%       0.000000    10.000000  2017.000000     1.000000     3.000000
# max       1.000000    12.000000  2019.000000     1.000000     4.000000
#
#        temperature    windspeed     humidity        casual        member  \
# count  3318.000000  3318.000000  3318.000000   3318.000000   3318.000000
# mean     15.303797    13.723930     0.636275   1606.927667   6117.928571
# std       9.484573     5.343355     0.147003   1513.868218   2956.782305
# min     -10.000000     0.000000     0.190000      2.000000     19.000000
# 25%       7.000000    10.000000     0.530000    475.250000   3783.250000
# 50%      16.000000    13.000000     0.640000   1175.000000   6074.000000
# 75%      24.000000    17.000000     0.750000   2253.500000   8471.500000
# max      34.000000    44.000000     0.990000  10173.000000  15419.000000
#
#               total
# count   3318.000000
# mean    7724.856239
# std     3882.272026
# min       21.000000
# 25%     4554.250000
# 50%     7561.500000
# 75%    11037.500000
# max    19113.000000

# %%
dfweather.isna().sum()
# Out:
# date           0
# holiday        0
# month          0
# year           0
# workingday     0
# season         0
# temperature    0
# windspeed      0
# humidity       0
# casual         0
# member         0
# total          0
# dtype: int64

# %%
dfweather.columns
# Out:
# Index(['date', 'holiday', 'month', 'year', 'workingday', 'season',
#        'temperature', 'windspeed', 'humidity', 'casual', 'member', 'total'],
#       dtype='object')

# %% [markdown]
# ### Pertanyaan
#
# 1. Bagaimana perubahan suhu dari musim ke musim? Berapa rata-rata suhu setiap musim?
# 2. Apakah informasi cuaca berkolerasi dengan total peminjaman sepeda?
# 3. Apakah hari libur dan hari kerja berkolerasi dengan total peminjaman sepeda?
# 4. Berapa rata-rata suhu, kecepatan angin, kelembapan, dan total peminjaman sepeda setiap bulan?

# %% [markdown]
# ### Analisis

# %% [markdown]
# #### 1. Bagaimana perubahan suhu dari musim ke musim? Berapa rata-rata suhu setiap musim?
#
# Informasi:<br>
# 1: Spring<br>
# 2: Summer<br>
# 3: Fall<br>
# 4: Winter<br>

# %%
season = ['Spring','Summer','Fall','Winter']

for i in range(len(season)):
    print(season[i])
    print('Mean temperature: {:0.2f}'.format(dfweather[dfweather['season'] == i+1]['temperature'].mean()))
    print('Median temperature: {:0.2f}'.format(dfweather[dfweather['season'] == i+1]['temperature'].median()))
    print('Std temperature: {:0.2f}'.format(dfweather[dfweather['season'] == i+1]['temperature'].std()))
    print('Min temperature: {:0.2f}'.format(dfweather[dfweather['season'] == i+1]['temperature'].min()))
    print('Max temperature: {:0.2f}'.format(dfweather[dfweather['season'] == i+1]['temperature'].max()))
    print('-'*34)
# Out:
# Spring
# Mean temperature: 14.34
# Median temperature: 15.00
# Std temperature: 6.76
# Min temperature: -5.00
# Max temperature: 30.00
# ----------------------------------
# Summer
# Mean temperature: 26.05
# Median temperature: 26.00
# Std temperature: 2.72
# Min temperature: 16.00
# Max temperature: 34.00
# ----------------------------------
# Fall
# Mean temperature: 16.03
# Median temperature: 16.00
# Std temperature: 6.91
# Min temperature: -1.00
# Max temperature: 30.00
# ----------------------------------
# Winter
# Mean temperature: 4.44
# Median temperature: 4.00
# Std temperature: 5.21
# Min temperature: -10.00
# Max temperature: 20.00
# ----------------------------------

# %%
plt.figure(figsize=(8,6))
plt.title('Temperature in Spring')
plt.hist(dfweather[dfweather['season']==1]['temperature'], color='#8bd665')

plt.axvline(dfweather[dfweather['season']==1]['temperature'].mean(), color='r', linestyle='dashed', linewidth=2)
plt.axvline(dfweather[dfweather['season']==1]['temperature'].median(), color='k', linewidth=2)

min_ylim, max_ylim = plt.ylim()
plt.text(dfweather[dfweather['season']==1]['temperature'].mean()*0.5, max_ylim*0.9, 'Mean: {:.2f}'.format(dfweather[dfweather['season']==1]['temperature'].mean()),c='r')

plt.text(dfweather[dfweather['season']==1]['temperature'].median()*1.1, max_ylim*0.9, 'Median: {:.2f}'.format(dfweather[dfweather['season']==1]['temperature'].median()),c='k')


plt.xlabel('Temperature (°C)')
plt.ylabel('Number of Days')

plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('Temperature in Summer')
plt.hist(dfweather[dfweather['season']==2]['temperature'], color='#d4ae3b')

plt.axvline(dfweather[dfweather['season']==2]['temperature'].mean(), color='r', linestyle='dashed', linewidth=2)
plt.axvline(dfweather[dfweather['season']==2]['temperature'].median(), color='g', linewidth=2)

min_ylim, max_ylim = plt.ylim()
plt.text(dfweather[dfweather['season']==2]['temperature'].mean()*0.8, max_ylim*0.9, 'Mean: {:.2f}'.format(dfweather[dfweather['season']==2]['temperature'].mean()),c='r')

plt.text(dfweather[dfweather['season']==2]['temperature'].median()*1.1, max_ylim*0.9, 'Median: {:.2f}'.format(dfweather[dfweather['season']==2]['temperature'].median()),c='g')


plt.xlabel('Temperature (°C)')
plt.ylabel('Number of Days')

plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('Temperature in Fall')
plt.hist(dfweather[dfweather['season']==3]['temperature'], color='#804e11')

plt.axvline(dfweather[dfweather['season']==3]['temperature'].mean(), color='r', linestyle='dashed', linewidth=2)
plt.axvline(dfweather[dfweather['season']==3]['temperature'].median(), color='g', linewidth=2)

min_ylim, max_ylim = plt.ylim()
plt.text(dfweather[dfweather['season']==3]['temperature'].mean()*0.6, max_ylim*0.9, 'Mean: {:.2f}'.format(dfweather[dfweather['season']==3]['temperature'].mean()),c='r')

plt.text(dfweather[dfweather['season']==3]['temperature'].median()*1.1, max_ylim*0.9, 'Median: {:.2f}'.format(dfweather[dfweather['season']==3]['temperature'].median()),c='g')


plt.xlabel('Temperature (°C)')
plt.ylabel('Number of Days')

plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('Temperature in Winter')
plt.hist(dfweather[dfweather['season']==4]['temperature'], color='#1a0557')

plt.axvline(dfweather[dfweather['season']==4]['temperature'].mean(), color='r', linestyle='dashed', linewidth=2)
plt.axvline(dfweather[dfweather['season']==4]['temperature'].median(), color='g', linewidth=2)

min_ylim, max_ylim = plt.ylim()
plt.text(dfweather[dfweather['season']==4]['temperature'].mean()*1.2, max_ylim*0.9, 'Mean: {:.2f}'.format(dfweather[dfweather['season']==4]['temperature'].mean()),c='r')

plt.text(dfweather[dfweather['season']==4]['temperature'].median()*-1.1, max_ylim*0.9, 'Median: {:.2f}'.format(dfweather[dfweather['season']==4]['temperature'].median()),c='g')


plt.xlabel('Temperature (°C)')
plt.ylabel('Number of Days')

plt.show()

# %% [markdown]
# #### Temuan
#
# Berdasarkan analisis pertanyaan pertama, temperature sangat tinggi pada saat Summer. Mean temperature terendah terdapat di Winter (mean: 4.44, standard deviasi: 5.21) dan mean temperature tertinggi terdapat di Summer (mean: 26.05, standard deviasi: 2.72). Di antaranya terdapat Spring (mean: 14.34, standard deviasi: 6.76) dan Fall (mean: 16.03, standard deviasi: 6.91). Karena temperature yang rendah di Winter, temperature yang cukup hangat di Spring dan Fall), serta temeperature yang hangat di Summer, semestinya temperature mempengaruhi jumlah sepeda yang disewa.

# %% [markdown]
# #### Rata-rata user (casual/member) per tahun berdasarkan season (time series)

# %%
plt.figure(figsize =(14,8))

for i in pd.unique(dfweather['year']):
    df_temp = dfweather[dfweather['year']==i]
    # menggunakan centered smoothing average agar seasonality-nya terlihat
    plt.plot(df_temp['casual'].reset_index()['casual'].rolling(window = 20).mean())

plt.legend(pd.unique(dfweather['year']))
plt.title('Casual')
plt.xlabel('Days')
plt.ylabel('Users')

plt.show()

# %%
plt.figure(figsize =(14,8))

for i in pd.unique(dfweather['year']):
    df_temp = dfweather[dfweather['year']==i]
    # menggunakan centered smoothing average agar seasonality-nya terlihat
    plt.plot(df_temp['member'].reset_index()['member'].rolling(window = 20).mean())

plt.legend(pd.unique(dfweather['year']))
plt.title('Member')
plt.xlabel('Days')
plt.ylabel('Users')

plt.show()

# %% [markdown]
# #### Temuan
#
# Season cukup tidak berpengaruh terhadap rata-rata pengguna member.

# %% [markdown]
# #### 2. Apakah informasi cuaca berkolerasi dengan total peminjaman sepeda?

# %%
dfweather.head()
# Out:
#          date  holiday  month  year  workingday  season  temperature  \
# 0  2010-09-20        0      9  2010           1       3           23
# 1  2010-09-21        0      9  2010           1       3           20
# 2  2010-09-22        0      9  2010           1       3           26
# 3  2010-09-23        0      9  2010           1       3           27
# 4  2010-09-24        0      9  2010           1       3           29
#
#    windspeed  humidity  casual  member  total
# 0         17      0.47      34     178    212
# 1         10      0.52     109     215    324
# 2         15      0.60     117     260    377
# 3          8      0.64     124     249    373
# 4         15      0.60     156     206    362

# %%
sns.pairplot(dfweather[['temperature', 'windspeed', 'humidity', 'casual', 'member', 'total']])

# %%
corr_cols = ['temperature','windspeed','humidity']

for i in corr_cols:
    print('Correlation {} to casual, member, and total'.format(i))
    print('Score Casual: {:0.3f}'.format(dfweather[i].corr(dfweather['casual'])))
    print('Score Member: {:0.3f}'.format(dfweather[i].corr(dfweather['member'])))
    print('Score Total: {:0.3f}'.format(dfweather[i].corr(dfweather['total'])))
    print('-'*40)
# Out:
# Correlation temperature to casual, member, and total
# Score Casual: 0.528
# Score Member: 0.534
# Score Total: 0.612
# ----------------------------------------
# Correlation windspeed to casual, member, and total
# Score Casual: -0.118
# Score Member: -0.105
# Score Total: -0.126
# ----------------------------------------
# Correlation humidity to casual, member, and total
# Score Casual: -0.041
# Score Member: -0.024
# Score Total: -0.034
# ----------------------------------------

# %% [markdown]
# #### Temuan
#
# Berdasarkan analisis pertanyaan kedua, hanya temperature yang memiliki nilai korelasi positif dengan jumlah sepeda yang disewa--baik pengguna member ataupun casual. Hal tersebut menandakan bahwa temperature mempengaruhi jumlah sepeda yang disewa.

# %% [markdown]
# #### 3. Apakah hari libur dan hari kerja berkolerasi dengan jumlah peminjaman sepeda?

# %%
corr_cols = ['holiday','workingday']

for i in corr_cols:
    print('Correlation {} to casual, member, and total'.format(i))
    print('Score casual: {:0.3f}'.format(dfweather[i].corr(dfweather['casual'])))
    print('Score member: {:0.3f}'.format(dfweather[i].corr(dfweather['member'])))
    print('Score total: {:0.3f}'.format(dfweather[i].corr(dfweather['total'])))
    print('-'*40)
# Out:
# Correlation holiday to casual, member, and total
# Score casual: 0.030
# Score member: -0.119
# Score total: -0.079
# ----------------------------------------
# Correlation workingday to casual, member, and total
# Score casual: -0.404
# Score member: 0.271
# Score total: 0.049
# ----------------------------------------

# %%
agg_holy = dfweather[['casual', 'member', 'holiday']].groupby('holiday').mean()
agg_holy.plot(kind = 'bar', figsize = (8,6), color = ['#026c6e', '#c2ed55']) 
plt.xticks(range(2), ['non holiday', 'holiday'], rotation = 0)

plt.show()

# %%
agg_holy = dfweather[['casual', 'member', 'workingday']].groupby('workingday').mean()
agg_holy.plot(kind = 'bar', figsize = (8,6), color = ['#026c6e', '#c2ed55']) 
plt.xticks(range(2), ['weekend', 'workingday'], rotation = 0)

plt.show()

# %%
# create new feature called weekday
dfweather.insert(5, 'weekday', dfweather['date'].dt.weekday)

# %%
dfweather.head()
# Out:
#         date  month  year  holiday  workingday  weekday  season  temperature  \
# 0 2010-09-20      9  2010        0           1        0       3           23
# 1 2010-09-21      9  2010        0           1        1       3           20
# 2 2010-09-22      9  2010        0           1        2       3           26
# 3 2010-09-23      9  2010        0           1        3       3           27
# 4 2010-09-24      9  2010        0           1        4       3           29
#
#    windspeed  humidity  casual  member  total
# 0         17      0.47      34     178    212
# 1         10      0.52     109     215    324
# 2         15      0.60     117     260    377
# 3          8      0.64     124     249    373
# 4         15      0.60     156     206    362

# %%
agg_work = dfweather[['casual', 'member', 'weekday']].groupby('weekday').mean()
agg_work.plot(figsize = (16,8), kind = 'bar', color = ['#026c6e', '#c2ed55'])
plt.xticks(range(7), ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'], rotation = 0)

plt.show()

# %% [markdown]
# #### Temuan
#
# Berdasarkan analisis pertanyaan ketiga, dapat dilihat bahwa pengguna terdaftar (member) lebih banyak menggunakan sepeda pada saat hari kerja, sedangkan hari libur dan akhir pekan meningkatkan jumlah pengguna casual.

# %% [markdown]
# #### 4. Berapa rata-rata suhu, kecepatan angin, kelembapan, dan total peminjaman sepeda setiap bulan?

# %%
mnths = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

list_twhc = []

for i in range(len(mnths)):
    print(mnths[i])
    print('Mean temperature: {:0.2f}'.format(dfweather[dfweather['month'] == i+1]['temperature'].mean()))
    print('Mean windspeed: {:0.2f}'.format(dfweather[dfweather['month'] == i+1]['windspeed'].mean()))
    print('Mean humidity: {:0.2f}'.format(dfweather[dfweather['month'] == i+1]['humidity'].mean()))
    print('Mean casual: {:0.2f}'.format(dfweather[dfweather['month'] == i+1]['casual'].mean()))
    print('Mean member: {:0.2f}'.format(dfweather[dfweather['month'] == i+1]['member'].mean()))
    print('Mean total: {:0.2f}'.format(dfweather[dfweather['month'] == i+1]['total'].mean()))
    print('-'*34)
    list_twhc.append([mnths[i], dfweather[dfweather['month'] == i+1]['temperature'].mean(), dfweather[dfweather['month'] == i+1]['windspeed'].mean(), dfweather[dfweather['month'] == i+1]['humidity'].mean(), dfweather[dfweather['month'] == i+1]['casual'].mean(), dfweather[dfweather['month'] == i+1]['member'].mean(), dfweather[dfweather['month'] == i+1]['total'].mean()])
# Out:
# January
# Mean temperature: 2.72
# Mean windspeed: 14.71
# Mean humidity: 0.61
# Mean casual: 380.18
# Mean member: 3678.41
# Mean total: 4058.59
# ----------------------------------
# February
# Mean temperature: 4.66
# Mean windspeed: 14.79
# Mean humidity: 0.60
# Mean casual: 514.41
# Mean member: 4240.58
# Mean total: 4754.99
# ----------------------------------
# March
# Mean temperature: 8.18
# Mean windspeed: 16.32
# Mean humidity: 0.57
# Mean casual: 1209.01
# Mean member: 5097.42
# Mean total: 6306.43
# ----------------------------------
# April
# Mean temperature: 14.72
# Mean windspeed: 15.69
# Mean humidity: 0.58
# Mean casual: 2299.51
# Mean member: 6657.07
# Mean total: 8956.58
# ----------------------------------
# May
# Mean temperature: 20.12
# Mean windspeed: 13.34
# Mean humidity: 0.68
# Mean casual: 2256.70
# Mean member: 7033.98
# Mean total: 9290.68
# ----------------------------------
# June
# Mean temperature: 24.76
# Mean windspeed: 13.47
# Mean humidity: 0.64
# Mean casual: 2378.34
# Mean member: 7756.27
# Mean total: 10134.60
# ----------------------------------
# July
# Mean temperature: 27.36
# Mean windspeed: 12.47
# Mean humidity: 0.65
# Mean casual: 2706.82
# Mean member: 7424.16
# Mean total: 10130.99
# ----------------------------------
# August
# Mean temperature: 26.00
# Mean windspeed: 11.91
# Mean humidity: 0.66
# Mean casual: 2480.37
# Mean member: 7716.26
# Mean total: 10196.63
# ----------------------------------
# September
# Mean temperature: 22.89
# Mean windspeed: 12.59
# Mean humidity: 0.69
# Mean casual: 1990.55
# Mean member: 7613.61
# Mean total: 9604.17
# ----------------------------------
# October
# Mean temperature: 15.91
# Mean windspeed: 13.24
# Mean humidity: 0.69
# Mean casual: 1553.38
# Mean member: 6845.08
# Mean total: 8398.45
# ----------------------------------
# November
# Mean temperature: 9.06
# Mean windspeed: 13.22
# Mean humidity: 0.62
# Mean casual: 916.18
# Mean member: 5126.48
# Mean total: 6042.66
# ----------------------------------
# December
# Mean temperature: 5.93
# Mean windspeed: 13.17
# Mean humidity: 0.65
# Mean casual: 491.47
# Mean member: 3941.66
# Mean total: 4433.13
# ----------------------------------

# %%
df_mean_month = pd.DataFrame(list_twhc, columns=['month','mean_temperature','mean_windspeed','mean_humidity','mean_casual', 'mean_member', 'mean_total'])
df_mean_month.head()
# Out:
#       month  mean_temperature  mean_windspeed  mean_humidity  mean_casual  \
# 0   January          2.718978       14.708029       0.606606   380.175182
# 1  February          4.656000       14.788000       0.601000   514.412000
# 2     March          8.182796       16.315412       0.568889  1209.010753
# 3     April         14.718519       15.685185       0.577000  2299.507407
# 4       May         20.121864       13.340502       0.676057  2256.702509
#
#    mean_member   mean_total
# 0  3678.412409  4058.587591
# 1  4240.580000  4754.992000
# 2  5097.422939  6306.433692
# 3  6657.070370  8956.577778
# 4  7033.982079  9290.684588

# %%
x_axis = np.arange(len(df_mean_month['month']))

plt.figure(figsize=(8,6))
plt.bar(x_axis, df_mean_month['mean_temperature'], color='#458a4b')
plt.xticks(x_axis, df_mean_month['month'], rotation=70)
plt.ylabel('Mean temperture')
plt.title('Temperature')

plt.figure(figsize=(8,6))
plt.bar(x_axis, df_mean_month['mean_windspeed'], color='#3b7d73')
plt.xticks(x_axis, df_mean_month['month'], rotation=70)
plt.ylabel('Mean windspeed')
plt.title('Windspeed')

plt.figure(figsize=(8,6))
plt.bar(x_axis, df_mean_month['mean_humidity'], color='#9e9d4a')
plt.xticks(x_axis, df_mean_month['month'], rotation=70)
plt.ylabel('Mean humidity')
plt.title('Humidity')

plt.figure(figsize=(8,6))
plt.bar(x_axis, df_mean_month['mean_casual'], color='#9adba7')
plt.xticks(x_axis, df_mean_month['month'], rotation=70)
plt.ylabel('Mean casual')
plt.title('Casual')

plt.figure(figsize=(8,6))
plt.bar(x_axis, df_mean_month['mean_member'], color='#d9b8e3')
plt.xticks(x_axis, df_mean_month['month'], rotation=70)
plt.ylabel('Mean member')
plt.title('Member')

plt.figure(figsize=(8,6))
plt.bar(x_axis, df_mean_month['mean_total'], color='#b05953')
plt.xticks(x_axis, df_mean_month['month'], rotation=70)
plt.ylabel('Mean total')
plt.title('Total')

plt.show()

# %% [markdown]
# #### Bagaimana temperature, windspeed, dan humidity mempengaruhi jumlah penyewa sepeda (member / casual)

# %%
def plot_it(feature, n_dec = 0):
    plot_data = dfweather[['casual', 'member', feature]]
    plot_data[feature] = plot_data[feature].apply(lambda x: round(x, n_dec))
    plot_data = plot_data.groupby(feature).mean().reset_index()

    f, (ax1, ax2) = plt.subplots(1, 2, figsize = (10,6))
    ax1.plot(plot_data[feature], plot_data['casual'], color = '#458a4b')
    ax1.set_title('Casual')
    ax1.set_ylabel('Average user')
    ax1.set_xlabel(feature)
    
    ax2.plot(plot_data[feature], plot_data['member'], color = '#b05953')
    ax2.set_title('Member')
    ax2.set_ylabel('Average user')
    ax2.set_xlabel(feature)
    
    f.tight_layout()
    
    return f, (ax1, ax2), plot_data

# %%
plot_it('temperature')
plt.show()
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plot_it('windspeed')
plt.show()
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plot_it('humidity', n_dec=1)
plt.show()
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# #### Temuan
#
# Berdasarkan analisis pertanyaan ketiga, secara umum ketika temperature naik, maka jumlah sepeda yang disewa perbulan juga naik. Hal ini sekaligus dapat memperlihatkan korelasi yang tinggi antara temperature dan jumlah sepeda yang disewa. Sedangkan windspeed dan humidity dari bulan ke bulan nilainya hampir konstan dan korelasinya dengan jumlah sepeda yang disewa masih belum cukup jelas (mungkin jumlah sepeda yang disewa independen terhadap dua variabel tersebut).

# %% [markdown]
# -----

# %%
print(dfweather['casual'].max())
print(dfweather['member'].max())
print(dfweather['total'].max())
# Out:
# 10173
# 15419
# 19113

# %%
dfweather[dfweather['casual'] == 10173]
# Out:
#            date  month  year  holiday  workingday  weekday  season  \
# 2389 2017-04-15      4  2017        0           0        5       1
#
#       temperature  windspeed  humidity  casual  member  total
# 2389           18         10      0.66   10173    6723  16896

# %%
dfweather[dfweather['member'] == 15419]
# Out:
#            date  month  year  holiday  workingday  weekday  season  \
# 2985 2018-12-03     12  2018        0           1        0       4
#
#       temperature  windspeed  humidity  casual  member  total
# 2985           12         16      0.63     935   15419  16354

# %%
dfweather[dfweather['total'] == 19113]
# Out:
#            date  month  year  holiday  workingday  weekday  season  \
# 2753 2018-04-14      4  2018        0           0        5       1
#
#       temperature  windspeed  humidity  casual  member  total
# 2753           23         21      0.52   10039    9074  19113

# %%
print('casual:', dfweather[(dfweather['temperature'] > 10) & (dfweather['windspeed'] < 25)]['casual'].mean())
print('member:', dfweather[(dfweather['temperature'] > 10) & (dfweather['windspeed'] < 25)]['member'].mean())
print('total:', dfweather[(dfweather['temperature'] > 10) & (dfweather['windspeed'] < 25)]['total'].mean())
# Out:
# casual: 2142.7917059377946
# member: 7201.223374175306
# total: 9344.0150801131

# %%
print('casual:', dfweather[(dfweather['temperature'] < 10) & (dfweather['windspeed'] > 25)]['casual'].mean())
print('member:', dfweather[(dfweather['temperature'] < 10) & (dfweather['windspeed'] > 25)]['member'].mean())
print('total:', dfweather[(dfweather['temperature'] < 10) & (dfweather['windspeed'] > 25)]['total'].mean())
# Out:
# casual: 366.56060606060606
# member: 3810.742424242424
# total: 4177.30303030303

# %% [markdown]
# Dari eksplorasi data mengenai berapa temperature dan berapa windspeed pada data pengguna terbesar dapat diperkirakan bahwa hari yang cukup baik untuk bersepeda adalah saat temperature lebih dari 10°C dan windspeed kurang dari 25 km/h. Mungkin hal ini dapat dijadikan salah satu pertimbangan ketika akan membuka station penyewaan sepeda baru di kota/negara bagian lain (dengan menghitung rata-rata temperature dan rata-rata windspeed).

# %% [markdown]
# ### Sumber Data untuk Final Project
# ------
#
# #### Capital Bike Sharing (data utama)
# Capital Bikeshare is metro DC's bikeshare system, with more than 4,300 bikes available at 500 stations across six jurisdictions: Washington, DC; Arlington, VA; Alexandria, VA; Montgomery County, MD; Prince George's County, MD; and Fairfax County, VA. Capital Bikeshare provides residents and visitors with a convenient, fun and affordable transportation option for getting from Point A to Point B. (source: https://www.capitalbikeshare.com/about)
#
# website: https://www.capitalbikeshare.com/<br>
# data: https://s3.amazonaws.com/capitalbikeshare-data/index.html
#
# #### Freemeteo (informasi cuaca)
# Weather forecasts, real time weather observations, historical data.
#
# Our weather system produces and provides detailed weather forecasts for all regions of our planet - both land and sea – tailored to the individual needs of people who require daily updates. More than 11 million geographic locations are investigated and detailed weather forecasts are produced, updated twice daily. Weather reports from thousands of certified online stations around the world are presented in real time providing accurate information on local weather conditions. Live satellite images, local or global weather maps and historical data are all available on our pages.
#
# Our goals are global reach and indiscriminative quality of service for all communities or individuals. The width of our vision, the equitable treatment of inhabited and uninhabited or densely and sparsely populated regions of this planet makes up our profile.
#
# website: https://freemeteo.com
#
# #### DC Department of Human Resources (informasi tanggal libur di DC)
# 2019: https://dchr.dc.gov/page/holiday-schedules<br>
# 2018: https://dchr.dc.gov/page/holiday-schedules-2018<br>
# 2017 & 2016: https://dchr.dc.gov/page/holiday-schedules-2016-and-2017<br>
# 2015 & 2014: https://dchr.dc.gov/page/holiday-schedules-2014-and-2015<br>
# 2013 & 2012: https://dchr.dc.gov/page/holiday-schedules-2012-and-2013<br>
# 2011 & 2010: https://dchr.dc.gov/page/holiday-schedules-2010-and-2011<br>
#
# website dchr: https://dchr.dc.gov/<br>
# website dc gov: https://dc.gov/
#
# #### National Centers for Environmental Information (informasi musim di AS)
# source: https://www.ncei.noaa.gov/news/meteorological-versus-astronomical-seasons<br>
# website: https://www.ncei.noaa.gov/
