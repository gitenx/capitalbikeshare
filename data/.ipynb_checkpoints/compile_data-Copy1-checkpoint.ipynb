# %%
import pandas as pd

# %% [markdown]
# ## Data Capital Bike Share 2010 to 2019 (per Oktober)
#
# All data downloaded from https://s3.amazonaws.com/capitalbikeshare-data/index.html

# %%
# count rent per-day
def count_rent_perday(dframe):
    dframe = dframe[['Start date', 'Member type']]
    dframe['Start date'] = pd.to_datetime(dframe['Start date']).dt.date
    dframe = dframe.groupby(['Start date', 'Member type']).size().unstack()
    dframe = dframe.reset_index().rename_axis(None, axis=1)

    return dframe

# %%
# 2010
d10 = pd.read_csv('raw/2010-capitalbikeshare-tripdata.csv')

# %%
d10 = count_rent_perday(d10)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d10.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d10.head()
# Out:
#    Start date  Casual  Member
# 0  2010-09-20      34     178
# 1  2010-09-21     109     215
# 2  2010-09-22     117     260
# 3  2010-09-23     124     249
# 4  2010-09-24     156     206

# %%
# 2011
d11 = pd.read_csv('raw/2011-capitalbikeshare-tripdata.csv')

# %%
d11 = count_rent_perday(d11)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d11.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d11.head()
# Out:
#    Start date  Casual  Member
# 0  2011-01-01     330     629
# 1  2011-01-02     130     651
# 2  2011-01-03     120    1181
# 3  2011-01-04     107    1429
# 4  2011-01-05      82    1489

# %%
# 2012
q112 = pd.read_csv('raw/2012Q1-capitalbikeshare-tripdata.csv')
q212 = pd.read_csv('raw/2012Q2-capitalbikeshare-tripdata.csv')
q312 = pd.read_csv('raw/2012Q3-capitalbikeshare-tripdata.csv')
q412 = pd.read_csv('raw/2012Q4-capitalbikeshare-tripdata.csv')

d12 = pd.concat([q112,q212,q312,q412])

# %%
d12.isna().sum()

# %%
d12 = count_rent_perday(d12)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d12.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d12.head()
# Out:
#    Start date  Casual  Member
# 0  2012-01-01     688    1572
# 1  2012-01-02     244    1693
# 2  2012-01-03      89    2130
# 3  2012-01-04      95    2262
# 4  2012-01-05     140    3111

# %%
# 2013
q113 = pd.read_csv('raw/2013Q1-capitalbikeshare-tripdata.csv')
q213 = pd.read_csv('raw/2013Q2-capitalbikeshare-tripdata.csv')
q313 = pd.read_csv('raw/2013Q3-capitalbikeshare-tripdata.csv')
q413 = pd.read_csv('raw/2013Q4-capitalbikeshare-tripdata.csv')

d13 = pd.concat([q113,q213,q313,q413])

# %%
d13.isna().sum()
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %%
d13 = count_rent_perday(d13)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d13.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d13.head()
# Out:
#    Start date  Casual  Member
# 0  2013-01-01     421    1543
# 1  2013-01-02     284    3389
# 2  2013-01-03     297    3547
# 3  2013-01-04     297    3781
# 4  2013-01-05     509    3008

# %%
# 2014
q114 = pd.read_csv('raw/2014Q1-capitalbikeshare-tripdata.csv')
q214 = pd.read_csv('raw/2014Q2-capitalbikeshare-tripdata.csv')
q314 = pd.read_csv('raw/2014Q3-capitalbikeshare-tripdata.csv')
q414 = pd.read_csv('raw/2014Q4-capitalbikeshare-tripdata.csv')

d14 = pd.concat([q114,q214,q314,q414])

# %%
d14.isna().sum()
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %%
d14 = count_rent_perday(d14)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d14.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d14.head()
# Out:
#    Start date  Casual  Member
# 0  2014-01-01     730    2281
# 1  2014-01-02     288    3028
# 2  2014-01-03      75    1533
# 3  2014-01-04     158    2084
# 4  2014-01-05     135    1925

# %%
# 2015
q115 = pd.read_csv('raw/2015Q1-capitalbikeshare-tripdata.csv')
q215 = pd.read_csv('raw/2015Q2-capitalbikeshare-tripdata.csv')
q315 = pd.read_csv('raw/2015Q3-capitalbikeshare-tripdata.csv')
q415 = pd.read_csv('raw/2015Q4-capitalbikeshare-tripdata.csv')

d15 = pd.concat([q115,q215,q315,q415])

# %%
d15.isna().sum()
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %%
d15 = count_rent_perday(d15)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d15.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d15.head()
# Out:
#    Start date  Casual  Member
# 0  2015-01-01     559    2019
# 1  2015-01-02     938    4170
# 2  2015-01-03     217    1486
# 3  2015-01-04     502    3156
# 4  2015-01-05     293    4929

# %%
# 2016
q116 = pd.read_csv('raw/2016Q1-capitalbikeshare-tripdata.csv')
q216 = pd.read_csv('raw/2016Q2-capitalbikeshare-tripdata.csv')
q316 = pd.read_csv('raw/2016Q3-capitalbikeshare-tripdata.csv')
q416 = pd.read_csv('raw/2016Q4-capitalbikeshare-tripdata.csv')

d16 = pd.concat([q116,q216,q316,q416])

# %%
d16.isna().sum()
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %%
d16 = count_rent_perday(d16)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d14.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d16.head()
# Out:
#    Start date  Casual  Member
# 0  2016-01-01     999    2221
# 1  2016-01-02    1522    3399
# 2  2016-01-03    1242    3723
# 3  2016-01-04     274    4859
# 4  2016-01-05     249    4601

# %%
# 2017
q117 = pd.read_csv('raw/2017Q1-capitalbikeshare-tripdata.csv')
q217 = pd.read_csv('raw/2017Q2-capitalbikeshare-tripdata.csv')
q317 = pd.read_csv('raw/2017Q3-capitalbikeshare-tripdata.csv')
q417 = pd.read_csv('raw/2017Q4-capitalbikeshare-tripdata.csv')

d17 = pd.concat([q117,q217,q317,q417])

# %%
d17.isna().sum()
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %%
d17 = count_rent_perday(d17)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d17.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d17.head()
# Out:
#    Start date  Casual  Member
# 0  2017-01-01    1580    2483
# 1  2017-01-02     181    1457
# 2  2017-01-03     254    3517
# 3  2017-01-04     748    6437
# 4  2017-01-05     402    5812

# %%
# 2018
jan18 = pd.read_csv('raw/201801-capitalbikeshare-tripdata.csv')
feb18 = pd.read_csv('raw/201802-capitalbikeshare-tripdata.csv')
mar18 = pd.read_csv('raw/201803-capitalbikeshare-tripdata.csv')
apr18 = pd.read_csv('raw/201804-capitalbikeshare-tripdata.csv')
mei18 = pd.read_csv('raw/201805-capitalbikeshare-tripdata.csv')
jun18 = pd.read_csv('raw/201806-capitalbikeshare-tripdata.csv')
jul18 = pd.read_csv('raw/201807-capitalbikeshare-tripdata.csv')
agu18 = pd.read_csv('raw/201808-capitalbikeshare-tripdata.csv')
sep18 = pd.read_csv('raw/201809-capitalbikeshare-tripdata.csv')
okt18 = pd.read_csv('raw/201810-capitalbikeshare-tripdata.csv')
nov18 = pd.read_csv('raw/201811-capitalbikeshare-tripdata.csv')
des18 = pd.read_csv('raw/201812-capitalbikeshare-tripdata.csv')

d18 = pd.concat([jan18,feb18,mar18,apr18,mei18,jun18,jul18,agu18,sep18,okt18,nov18,des18])

# %%
d18.isna().sum()
# Out:
# Duration                0
# Start date              0
# End date                0
# Start station number    0
# Start station           0
# End station number      0
# End station             0
# Bike number             0
# Member type             0
# dtype: int64

# %%
d18 = count_rent_perday(d18)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d14.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d18.head()
# Out:
#    Start date  Casual  Member
# 0  2018-01-01     145    1068
# 1  2018-01-02     179    3613
# 2  2018-01-03     279    4469
# 3  2018-01-04      66    2302
# 4  2018-01-05      62    2647

# %%
# 2019
jan19 = pd.read_csv('raw/201901-capitalbikeshare-tripdata.csv')
feb19 = pd.read_csv('raw/201902-capitalbikeshare-tripdata.csv')
mar19 = pd.read_csv('raw/201903-capitalbikeshare-tripdata.csv')
apr19 = pd.read_csv('raw/201904-capitalbikeshare-tripdata.csv')
mei19 = pd.read_csv('raw/201905-capitalbikeshare-tripdata.csv')
jun19 = pd.read_csv('raw/201906-capitalbikeshare-tripdata.csv')
jul19 = pd.read_csv('raw/201907-capitalbikeshare-tripdata.csv')
agu19 = pd.read_csv('raw/201908-capitalbikeshare-tripdata.csv')
sep19 = pd.read_csv('raw/201909-capitalbikeshare-tripdata.csv')
okt19 = pd.read_csv('raw/201910-capitalbikeshare-tripdata.csv')

d19 = pd.concat([jan19,feb19,mar19,apr19,mei19,jun19,jul19,agu19,sep19,okt19])

# %%
d19.isna().sum()
# Out:
# Duration                 0
# Start date               0
# End date                 0
# Start station number     0
# Start station            0
# End station number       0
# End station              0
# Bike number             14
# Member type              0
# dtype: int64

# %%
d19 = count_rent_perday(d19)
# Out:
# C:\Users\EN\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
d19.isna().sum()
# Out:
# Start date    0
# Casual        0
# Member        0
# dtype: int64

# %%
d19.head()
# Out:
#    Start date  Casual  Member
# 0  2019-01-01    1083    3457
# 1  2019-01-02     660    5907
# 2  2019-01-03     938    6666
# 3  2019-01-04     848    6514
# 4  2019-01-05     701    4405

# %%
dsb = pd.concat([d10,d11,d12,d13,d14,d15,d16,d17,d18,d19])

# %%
dsb['total'] = dsb['Casual'] + dsb['Member']

# %%
dsb.head()
# Out:
#    Start date  Casual  Member  total
# 0  2010-09-20      34     178    212
# 1  2010-09-21     109     215    324
# 2  2010-09-22     117     260    377
# 3  2010-09-23     124     249    373
# 4  2010-09-24     156     206    362

# %%
dsb.columns = ['date', 'casual', 'member', 'total']

# %%
len(dsb)
# Out:
# 3325

# %%
dsb.head()
# Out:
#          date  casual  member  total
# 0  2010-09-20      34     178    212
# 1  2010-09-21     109     215    324
# 2  2010-09-22     117     260    377
# 3  2010-09-23     124     249    373
# 4  2010-09-24     156     206    362

# %%
dsb.to_csv('capitalbikeshare_data_only.csv')

# %% [markdown]
# ## Insert Holiday (1) or Not Holiday (0)
#
# Washington D.C. public holiday extracted from http://dchr.dc.gov/page/holiday-schedule

# %%
dholi = pd.read_csv('raw/holiday_raw.csv')

# %%
dholi['date'] = pd.to_datetime(dholi['date']).dt.date

# %%
hd = []

for i in dholi['date']:
    hd.append(str(i))

len(hd)
# Out:
# 135

# %%
holiday = []
for j in dsb['date']:
    if str(j) in hd:
        holiday.append(1)
    else:
        holiday.append(0)

print(len(holiday), holiday.count(1))
# Out:
# 3325 102

# %%
# insert list holiday ke dsb
dsb.insert(1, 'holiday', holiday)

# %%
dsb.head()
# Out:
#          date  holiday  casual  member  total
# 0  2010-09-20        0      34     178    212
# 1  2010-09-21        0     109     215    324
# 2  2010-09-22        0     117     260    377
# 3  2010-09-23        0     124     249    373
# 4  2010-09-24        0     156     206    362

# %% [markdown]
# ## Insert Workingday (1) / Not Workingday (0)
#
# Workingday: Monday to Friday

# %%
import datetime
import calendar
workingday = []

for i in dsb['date']:
    print(calendar.day_name[datetime.datetime.strptime(str(i), '%Y-%m-%d').weekday()], datetime.datetime.strptime(str(i), '%Y-%m-%d').weekday())
    if datetime.datetime.strptime(str(i), '%Y-%m-%d').weekday() > 4:
        workingday.append(0)
    else:
        workingday.append(1)
# Out:
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# Saturday 5
# Sunday 6
# Monday 0
# Tuesday 1
# Wednesday 2
# Thursday 3
# Friday 4
# ...

# %%
dsb.insert(2, 'workingday', workingday)

# %%
dsb.head()
# Out:
#          date  holiday  workingday  casual  member  total
# 0  2010-09-20        0           1      34     178    212
# 1  2010-09-21        0           1     109     215    324
# 2  2010-09-22        0           1     117     260    377
# 3  2010-09-23        0           1     124     249    373
# 4  2010-09-24        0           1     156     206    362

# %% [markdown]
# ## Insert Season
#
# Season based on meteorological seasons<br>
#
# 1: Spring (started at March 1)<br>
# 2: Summer (started at June 1)<br>
# 3: Fall (started at September 1)<br>
# 4: Winter (started at December 1)<br>
#
# source: https://www.ncei.noaa.gov/news/meteorological-versus-astronomical-seasons

# %%
spring = datetime.date(2019,3,1)
spring = spring.strftime('%m-%d')

summer = datetime.date(2019,6,1)
summer = summer.strftime('%m-%d')

fall = datetime.date(2019,9,1)
fall = fall.strftime('%m-%d')

winter = datetime.date(2019,12,1)
winter = winter.strftime('%m-%d')

season = []

for i in dsb['date']:
    hari = datetime.datetime.strptime(str(i), '%Y-%m-%d').date()
    hari = hari.strftime('%m-%d')
    if hari >= spring and hari < summer:
        season.append(1)
    elif hari >= summer and hari < fall:
        season.append(2)
    elif hari >= fall and hari < winter:
        season.append(3)
    elif hari < spring or hari >= winter:
        season.append(4)
    
#     print(hari)

len(season)
# Out:
# 3325

# %%
dsb.insert(3, 'season', season)

# %%
dsb.head()
# Out:
#          date  holiday  workingday  season  casual  member  total
# 0  2010-09-20        0           1       3      34     178    212
# 1  2010-09-21        0           1       3     109     215    324
# 2  2010-09-22        0           1       3     117     260    377
# 3  2010-09-23        0           1       3     124     249    373
# 4  2010-09-24        0           1       3     156     206    362

# %% [markdown]
# ## Insert Weather (temperature, wind speed, humidity, desc weather)
#
# The temperature, wind speed, humidity, and desc weather data extracted from https://freemeteo.co.id

# %%
dweather = pd.read_csv('raw/weather_monthly_raw.csv')

# %%
dweather.head()
# Out:
#          date  temperature  windspeed  humidity   desc_weather
# 0  2010-01-01            2         14      0.71  Partly cloudy
# 1  2010-01-02           -3         33      0.43     Few clouds
# 2  2010-01-03           -5         31      0.42     Few clouds
# 3  2010-01-04           -2         20      0.46  Partly cloudy
# 4  2010-01-05           -1         20      0.46         Cloudy

# %%
len(dweather)
# Out:
# 3584

# %%
dweather['date'] = pd.to_datetime(dweather['date'], format='%Y-%m-%d').dt.date

# %%
dcbs = dsb.merge(dweather, on='date')

# %%
dcbs.head()
# Out:
#          date  holiday  workingday  season  casual  member  total  \
# 0  2010-09-20        0           1       3      34     178    212
# 1  2010-09-21        0           1       3     109     215    324
# 2  2010-09-22        0           1       3     117     260    377
# 3  2010-09-23        0           1       3     124     249    373
# 4  2010-09-24        0           1       3     156     206    362
#
#    temperature  windspeed  humidity   desc_weather
# 0           23         17      0.47  Clear weather
# 1           20         10      0.52  Clear weather
# 2           26         15      0.60     Few clouds
# 3           27          8      0.64     Few clouds
# 4           29         15      0.60  Clear weather

# %%
len(dcbs)
# Out:
# 3318

# %%
dcbs.columns.tolist()
# Out:
# ['date',
#  'holiday',
#  'workingday',
#  'season',
#  'casual',
#  'member',
#  'total',
#  'temperature',
#  'windspeed',
#  'humidity',
#  'desc_weather']

# %%
dcbs = dcbs[['date','holiday','workingday','season','temperature','windspeed','humidity', 'desc_weather','casual','member','total']]

# %%
dcbs.head()
# Out:
#          date  holiday  workingday  season  temperature  windspeed  humidity  \
# 0  2010-09-20        0           1       3           23         17      0.47
# 1  2010-09-21        0           1       3           20         10      0.52
# 2  2010-09-22        0           1       3           26         15      0.60
# 3  2010-09-23        0           1       3           27          8      0.64
# 4  2010-09-24        0           1       3           29         15      0.60
#
#     desc_weather  casual  member  total
# 0  Clear weather      34     178    212
# 1  Clear weather     109     215    324
# 2     Few clouds     117     260    377
# 3     Few clouds     124     249    373
# 4  Clear weather     156     206    362

# %%
dcbs['date'] = pd.to_datetime(dcbs['date'])

# %% [markdown]
# ## Split date to new columns (month and year)

# %%
dcbs.insert(1,'month',dcbs['date'].dt.month)
dcbs.insert(2,'year',dcbs['date'].dt.year)

dcbs.head()
# Out:
#         date  month  year  holiday  workingday  season  temperature  \
# 0 2010-09-20      9  2010        0           1       3           23
# 1 2010-09-21      9  2010        0           1       3           20
# 2 2010-09-22      9  2010        0           1       3           26
# 3 2010-09-23      9  2010        0           1       3           27
# 4 2010-09-24      9  2010        0           1       3           29
#
#    windspeed  humidity   desc_weather  casual  member  total
# 0         17      0.47  Clear weather      34     178    212
# 1         10      0.52  Clear weather     109     215    324
# 2         15      0.60     Few clouds     117     260    377
# 3          8      0.64     Few clouds     124     249    373
# 4         15      0.60  Clear weather     156     206    362

# %% [markdown]
# ## Group desc_weather and drop it
#
# 1:Clear weather<br>
# 2:Few clouds<br>
# 3:Partly cloudy<br>
# 4:Cloudy<br>
# 5:Rain<br>
# 6:Thunderstorm<br>
# 7:Snow<br>
# 8:Snowstorm

# %%
weather = []
cw = ['Clear weather', 'Few clouds', 'Partly cloudy', 'Cloudy', 'Rain', 'Thunderstorm', 'Snow', 'Snowstorm']

for i in dcbs['desc_weather']:
    if i in cw:
        weather.append(cw.index(i)+1)

len(weather)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-52e4971d5d64> in <module>
#       2 cw = ['Clear weather', 'Few clouds', 'Partly cloudy', 'Cloudy', 'Rain', 'Thunderstorm', 'Snow', 'Snowstorm']
#       3
# ----> 4 for i in dcbs['desc_weather']:
#       5     if i in cw:
#       6         weather.append(cw.index(i)+1)
#
# NameError: name 'dcbs' is not defined

# %%
dcbs.insert(9, 'weather', weather)

dcbs.head()
# Out:
#         date  month  year  holiday  workingday  season  temperature  \
# 0 2010-09-20      9  2010        0           1       3           23
# 1 2010-09-21      9  2010        0           1       3           20
# 2 2010-09-22      9  2010        0           1       3           26
# 3 2010-09-23      9  2010        0           1       3           27
# 4 2010-09-24      9  2010        0           1       3           29
#
#    windspeed  humidity  weather   desc_weather  rent_count
# 0         17      0.47        1  Clear weather         212
# 1         10      0.52        1  Clear weather         324
# 2         15      0.60        2     Few clouds         377
# 3          8      0.64        2     Few clouds         373
# 4         15      0.60        1  Clear weather         362

# %%
dcbs.drop('desc_weather', axis=1, inplace=True)

dcbs.head()
# Out:
#         date  month  year  holiday  workingday  season  temperature  \
# 0 2010-09-20      9  2010        0           1       3           23
# 1 2010-09-21      9  2010        0           1       3           20
# 2 2010-09-22      9  2010        0           1       3           26
# 3 2010-09-23      9  2010        0           1       3           27
# 4 2010-09-24      9  2010        0           1       3           29
#
#    windspeed  humidity  weather  rent_count
# 0         17      0.47        1         212
# 1         10      0.52        1         324
# 2         15      0.60        2         377
# 3          8      0.64        2         373
# 4         15      0.60        1         362

# %% [markdown]
# ## TO CSV!

# %%
dcbs.to_csv('dataset_capitalbikesharing.csv', index=False)
